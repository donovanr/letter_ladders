# %% [markdown]
# # Try out letter ladder code on some different word corpuses

# %%
import networkx as nx
import letter_ladders as ll

# %% [markdown]
# ## Built in dictionary

# %%
# get default dict into list, add all words as nodes to graph, group words by length
built_in_wordlist = [w.strip() for w in open('/usr/share/dict/words') if len(w.strip()) > 1 and w.strip().islower()]
built_in_wordlist.extend(['a','i'])
built_in_wordlist_graph = nx.DiGraph();
built_in_wordlist_graph.add_nodes_from(built_in_wordlist)
built_in_wordlist_grouped_by_len = ll.group_wordlist_by_len(built_in_wordlist)

# add all possible edges to the entire wordlist graph
for i in xrange(1,max([len(word) for word in wordlist])+1):
    ll.ersosion_filter_nx(i,built_in_wordlist_graph,wordlist_grouped_by_len)

# save the graph -- this took a while   
nx.write_gpickle(built_in_wordlist_graph,"wordlist_graph.gpickle")

# %%
# use this cell if you've already built the graph
built_in_wordlist_graph = nx.read_gpickle("wordlist_graph.gpickle")

# %%
# find long letter ladders!
all_long_paths_built_in = ll.find_all_longest_and_next_longest_paths(built_in_wordlist_graph);
ll.print_paths(all_long_paths_built_in)
# Out:
# length of longest path is 11
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'ach', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ba', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bac', 'ba', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'ach', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ra', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'ach', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ah', 'a']
# ['abranchiate', 'branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ra', 'a']
#
#
# length of next longest path is 10
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'ach', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ba', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bac', 'ba', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'ach', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ra', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'ach', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ah', 'a']
# ['abranchial', 'branchial', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ra', 'a']
# ['sparringly', 'sparingly', 'springly', 'springy', 'spring', 'sprig', 'spig', 'sig', 'si', 'i']
# ['sparringly', 'sparingly', 'springly', 'springy', 'spring', 'sprig', 'spig', 'pig', 'pi', 'i']
# ['sparringly', 'sparingly', 'springly', 'springy', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['camphoroyl', 'camphoryl', 'camphory', 'camphor', 'campho', 'campo', 'camp', 'cap', 'ca', 'a']
# ['camphoroyl', 'camphoryl', 'camphory', 'camphor', 'campho', 'campo', 'camp', 'cam', 'ca', 'a']
# ['camphoroyl', 'camphoryl', 'camphory', 'camphor', 'campho', 'campo', 'camp', 'cam', 'am', 'a']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'hing', 'ing', 'in', 'i']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'hing', 'hin', 'in', 'i']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'hing', 'hin', 'hi', 'i']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'chin', 'hin', 'in', 'i']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'chin', 'hin', 'hi', 'i']
# ['unparching', 'uparching', 'parching', 'arching', 'aching', 'ching', 'chin', 'chi', 'hi', 'i']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'ach', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bah', 'ba', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'bach', 'bac', 'ba', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'ach', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'brach', 'rach', 'rah', 'ra', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'ach', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ah', 'a']
# ['branchiate', 'branchiae', 'branchia', 'branchi', 'branch', 'ranch', 'rach', 'rah', 'ra', 'a']

# %% [markdown]
# ## Scrabble dictionary

# %% [markdown]
# from https://raw.githubusercontent.com/bahmutov/prefix-dictionary/master/ospd4.txt

# %%
# get default dict into list, add all words as nodes to graph, group words by length
with open("ospd4.txt") as word_file:
    scrabble_wordlist = list(w.strip() for w in word_file if len(w.strip()) > 1 and w.strip().islower() and w.strip().isalpha())
scrabble_wordlist.extend(['a','i'])
scrabble_wordlist_graph = nx.DiGraph();
scrabble_wordlist_graph.add_nodes_from(scrabble_wordlist)
scrabble_wordlist_grouped_by_len = ll.group_wordlist_by_len(scrabble_wordlist)

# add all possible edges to the entire wordlist graph
for i in xrange(1,max([len(word) for word in wordlist])+1):
    ll.ersosion_filter_nx(i,scrabble_wordlist_graph,wordlist_grouped_by_len)

# save the graph -- this took a while   
nx.write_gpickle(scrabble_wordlist_graph,"scrabble_wordlist_graph.gpickle")

# %%
scrabble_wordlist_graph = nx.read_gpickle("scrabble_wordlist_graph.gpickle")

# %%
# find long letter ladders!
all_long_paths_scrabble = ll.find_all_longest_and_next_longest_paths(scrabble_wordlist_graph);
ll.print_paths(all_long_paths_scrabble)
# Out:
# length of longest path is 11
# ['complecting', 'completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pin', 'in', 'i']
# ['complecting', 'completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['complecting', 'completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pig', 'pi', 'i']
#
#
# length of next longest path is 10
# ['parcheesis', 'parchesis', 'parchesi', 'parches', 'arches', 'aches', 'aces', 'ace', 'ae', 'a']
# ['parcheesis', 'parchesis', 'parchesi', 'parches', 'arches', 'aches', 'ache', 'ace', 'ae', 'a']
# ['parcheesis', 'parcheesi', 'parchesi', 'parches', 'arches', 'aches', 'aces', 'ace', 'ae', 'a']
# ['parcheesis', 'parcheesi', 'parchesi', 'parches', 'arches', 'aches', 'ache', 'ace', 'ae', 'a']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'satin', 'sain', 'ain', 'ai', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'satin', 'sain', 'ain', 'in', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'satin', 'sain', 'sin', 'in', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'satin', 'sain', 'sin', 'si', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'sting', 'ting', 'tin', 'in', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'sting', 'ting', 'tin', 'ti', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'sting', 'sing', 'sin', 'in', 'i']
# ['insolating', 'isolating', 'solating', 'slating', 'sating', 'sting', 'sing', 'sin', 'si', 'i']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['maceraters', 'macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['maceraters', 'macerater', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['discussers', 'discusses', 'discuses', 'discuss', 'discus', 'discs', 'diss', 'dis', 'is', 'i']
# ['discussers', 'discusses', 'discuses', 'discuss', 'discus', 'discs', 'disc', 'dis', 'is', 'i']
# ['scratchers', 'scratches', 'cratches', 'catches', 'caches', 'aches', 'aces', 'ace', 'ae', 'a']
# ['scratchers', 'scratches', 'cratches', 'catches', 'caches', 'aches', 'ache', 'ace', 'ae', 'a']
# ['scratchers', 'scratches', 'cratches', 'catches', 'caches', 'cache', 'ache', 'ace', 'ae', 'a']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tae', 'ae', 'a']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tae', 'ta', 'a']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'am', 'a']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['princesses', 'princesse', 'princess', 'princes', 'prices', 'pries', 'pies', 'pis', 'is', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prices', 'pries', 'pies', 'pis', 'pi', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prices', 'pries', 'pies', 'pie', 'pi', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prices', 'price', 'pice', 'pic', 'pi', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prices', 'price', 'pice', 'pie', 'pi', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prince', 'price', 'pice', 'pic', 'pi', 'i']
# ['princesses', 'princesse', 'princess', 'princes', 'prince', 'price', 'pice', 'pie', 'pi', 'i']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'gasses', 'gases', 'gaes', 'gae', 'ae', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'gasses', 'gases', 'gaes', 'gas', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'lasses', 'lases', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'lasses', 'lases', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'lasses', 'lases', 'lass', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'lasses', 'lases', 'lase', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glasses', 'lasses', 'lases', 'lase', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lasses', 'lases', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lasses', 'lases', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lasses', 'lases', 'lass', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lasses', 'lases', 'lase', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lasses', 'lases', 'lase', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassis', 'lassi', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassis', 'lassi', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassis', 'lassi', 'lass', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassie', 'lassi', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassie', 'lassi', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'lassies', 'lassie', 'lassi', 'lass', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassies', 'glassie', 'lassie', 'lassi', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glassie', 'lassie', 'lassi', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassies', 'glassie', 'lassie', 'lassi', 'lass', 'las', 'la', 'a']
# ['glassiness', 'glassines', 'glassine', 'glassie', 'lassie', 'lassi', 'lass', 'ass', 'as', 'a']
# ['glassiness', 'glassines', 'glassine', 'glassie', 'lassie', 'lassi', 'lass', 'las', 'as', 'a']
# ['glassiness', 'glassines', 'glassine', 'glassie', 'lassie', 'lassi', 'lass', 'las', 'la', 'a']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'wites', 'wits', 'wis', 'is', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'wites', 'wits', 'its', 'is', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'wites', 'wits', 'its', 'it', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'wites', 'wits', 'wit', 'it', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'wites', 'wite', 'wit', 'it', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'withe', 'wite', 'wit', 'it', 'i']
# ['twitchiest', 'witchiest', 'withiest', 'withies', 'withes', 'withe', 'with', 'wit', 'it', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'sain', 'ain', 'ai', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'sain', 'ain', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'sain', 'sin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'sain', 'sin', 'si', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'tain', 'ain', 'ai', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'tain', 'ain', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'tain', 'tin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'stain', 'tain', 'tin', 'ti', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'satin', 'sain', 'ain', 'ai', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'satin', 'sain', 'ain', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'satin', 'sain', 'sin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'statin', 'satin', 'sain', 'sin', 'si', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'satin', 'sain', 'ain', 'ai', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'satin', 'sain', 'ain', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'satin', 'sain', 'sin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'satin', 'sain', 'sin', 'si', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'sting', 'ting', 'tin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'sting', 'ting', 'tin', 'ti', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'sting', 'sing', 'sin', 'in', 'i']
# ['restarting', 'restating', 'estating', 'stating', 'sating', 'sting', 'sing', 'sin', 'si', 'i']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangles', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangles', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangler', 'strangle', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangler', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['stranglers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pin', 'in', 'i']
# ['completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['completing', 'competing', 'compting', 'comping', 'coping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['strappings', 'strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strappings', 'strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strappings', 'strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strappings', 'strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strappings', 'strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strappings', 'strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strappings', 'trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strappings', 'trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strappings', 'trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strappings', 'trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strappings', 'trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strappings', 'trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strappings', 'trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strappings', 'trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strappings', 'trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'sanes', 'anes', 'ane', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'sanes', 'anes', 'ane', 'an', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'sae', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'sae', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'sae', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'sanes', 'anes', 'ane', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'sanes', 'anes', 'ane', 'an', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'sanes', 'sane', 'sae', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stanes', 'stane', 'sane', 'sae', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'sae', 'ae', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrasas', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassas', 'madrassa', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasas', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrasahs', 'madrasah', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrassa', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'as', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'ars', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'as', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mas', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mars', 'mar', 'ma', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ar', 'a']
# ['madrassahs', 'madrassah', 'madrasah', 'madrasa', 'madras', 'maras', 'mara', 'mar', 'ma', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tae', 'ae', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tae', 'ta', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tae', 'ae', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tae', 'ta', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'ape', 'ae', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'taped', 'aped', 'ape', 'ae', 'a']
# ['stampeders', 'stampeder', 'stampede', 'stamped', 'tamped', 'amped', 'aped', 'ape', 'ae', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tae', 'ae', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tae', 'ta', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tae', 'ae', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tae', 'ta', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'ape', 'ae', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'aped', 'ape', 'ae', 'a']
# ['stampeders', 'stampedes', 'stampede', 'stamped', 'tamped', 'amped', 'aped', 'ape', 'ae', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'estranger', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'estranger', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'estranges', 'estrange', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'estranges', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'strangers', 'stranger', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'sang', 'sag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'sag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'stag', 'tag', 'ta', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ag', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tag', 'ta', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'an', 'a']
# ['estrangers', 'strangers', 'stranges', 'strange', 'strang', 'stang', 'tang', 'tan', 'ta', 'a']

# %% [markdown]
# ## Scowl 60 word list

# %% [markdown]
# from http://app.aspell.net/create; remover header before processing below

# %%
# get default dict into list, add all words as nodes to graph, group words by length
with open("scowl_60.txt") as word_file:
    scowl_60_wordlist = list(w.strip() for w in word_file if len(w.strip()) > 1 and w.strip().islower() and w.strip().isalpha())
scowl_60_wordlist.extend(['a','i'])
scowl_60_wordlist_graph = nx.DiGraph();
scowl_60_wordlist_graph.add_nodes_from(scrabble_wordlist)
scowl_60_wordlist_grouped_by_len = ll.group_wordlist_by_len(scowl_60_wordlist)

# add all possible edges to the entire wordlist graph
for i in xrange(1,max([len(word) for word in wordlist])+1):
    ll.ersosion_filter_nx(i,scowl_60_wordlist_graph,wordlist_grouped_by_len)

# save the graph -- this took a while   
nx.write_gpickle(scowl_60_wordlist_graph,"scowl_60_wordlist_graph.gpickle")

# %%
scowl_60_wordlist_graph = nx.read_gpickle("scowl_60_wordlist_graph.gpickle")

# %%
# find long letter ladders!
all_long_paths_scowl_60 = ll.find_all_longest_and_next_longest_paths(scowl_60_wordlist_graph);
ll.print_paths(all_long_paths_scowl_60)
# Out:
# length of longest path is 10
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
#
#
# length of next longest path is 9
# ['stampeded', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['sparkling', 'sparking', 'sparing', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'ea', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'as', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'as', 'a']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sis', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'ins', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'ins', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sis', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'ins', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'ins', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'sing', 'sin', 'in', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['roadsters', 'roasters', 'roaster', 'raster', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roasters', 'roaster', 'raster', 'rater', 'rate', 'rat', 'at', 'a']
# ['roadsters', 'roadster', 'roaster', 'raster', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roadster', 'roaster', 'raster', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rats', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'rattler', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'prattler', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'prattler', 'rattler', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['switchers', 'switches', 'witches', 'withes', 'withe', 'with', 'wit', 'it', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'ate', 'at', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'pace', 'ace', 'ac', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'aces', 'ace', 'ac', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'peace', 'pace', 'ace', 'ac', 'a']
# ['discusses', 'discuses', 'discuss', 'discus', 'discs', 'disc', 'dis', 'is', 'i']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'craps', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'craps', 'caps', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'capes', 'caps', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'crapes', 'capes', 'cape', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scrape', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scrape', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scrape', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scraps', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scraps', 'craps', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scrapes', 'scraps', 'craps', 'caps', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scraper', 'scrape', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scraper', 'scrape', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappers', 'scrapers', 'scraper', 'scrape', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapper', 'scraper', 'scrape', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappers', 'scrapper', 'scraper', 'scrape', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappers', 'scrapper', 'scraper', 'scrape', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['ministers', 'minsters', 'minster', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minster', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'mines', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'mines', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['starvings', 'starving', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['starvings', 'starving', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['starvings', 'starving', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pin', 'in', 'i']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pin', 'pi', 'i']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pig', 'pi', 'i']
# ['drownings', 'drowning', 'downing', 'owning', 'owing', 'wing', 'win', 'in', 'i']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pin', 'in', 'i']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pin', 'pi', 'i']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pig', 'pi', 'i']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'site', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pis', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pis', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pie', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'site', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprite', 'spite', 'spit', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprite', 'spite', 'spit', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprite', 'spite', 'spit', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprite', 'spite', 'site', 'sit', 'it', 'i']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tams', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tams', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'taps', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'tat', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'tat', 'ta', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'sat', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'sate', 'ate', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'sate', 'sat', 'at', 'a']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'colons', 'coons', 'coos', 'cos', 'cs']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'colons', 'coons', 'cons', 'cos', 'cs']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'clones', 'cones', 'cons', 'cos', 'cs']
# ['groupings', 'grouping', 'groping', 'roping', 'oping', 'ping', 'pin', 'in', 'i']
# ['groupings', 'grouping', 'groping', 'roping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['groupings', 'grouping', 'groping', 'roping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']

# %% [markdown]
# ## Scowl 70 word list

# %% [markdown]
# from http://app.aspell.net/create

# %%
# get default dict into list, add all words as nodes to graph, group words by length
with open("scowl_70.txt") as word_file:
    scowl_70_wordlist = list(w.strip() for w in word_file if len(w.strip()) > 1 and w.strip().islower() and w.strip().isalpha())
scowl_70_wordlist.extend(['a','i'])
scowl_70_wordlist_graph = nx.DiGraph();
scowl_70_wordlist_graph.add_nodes_from(scrabble_wordlist)
scowl_70_wordlist_grouped_by_len = ll.group_wordlist_by_len(scowl_70_wordlist)

# add all possible edges to the entire wordlist graph
for i in xrange(1,max([len(word) for word in wordlist])+1):
    ll.ersosion_filter_nx(i,scowl_70_wordlist_graph,wordlist_grouped_by_len)

# save the graph -- this took a while   
nx.write_gpickle(scowl_70_wordlist_graph,"scowl_70_wordlist_graph.gpickle")

# %%
scowl_70_wordlist_graph = nx.read_gpickle("scowl_70_wordlist_graph.gpickle")

# %%
# find long letter ladders!
all_long_paths_scowl_70 = ll.find_all_longest_and_next_longest_paths(scowl_70_wordlist_graph);
ll.print_paths(all_long_paths_scowl_70)
# Out:
# length of longest path is 10
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunchest', 'staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splittings', 'splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splittings', 'splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splittings', 'splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'am', 'a']
# ['streambeds', 'streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'ta', 'a']
#
#
# length of next longest path is 9
# ['shiftings', 'shifting', 'sifting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['shiftings', 'shifting', 'sifting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['shiftings', 'shifting', 'sifting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['shiftings', 'shifting', 'sifting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['shiftings', 'shifting', 'sifting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['shiftings', 'siftings', 'sifting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['shiftings', 'siftings', 'sifting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['shiftings', 'siftings', 'sifting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['shiftings', 'siftings', 'sifting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['shiftings', 'siftings', 'sifting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['stoppling', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'in', 'i']
# ['stoppling', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['stoppling', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['stoppling', 'toppling', 'topping', 'toping', 'oping', 'ping', 'pin', 'in', 'i']
# ['stoppling', 'toppling', 'topping', 'toping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['stoppling', 'toppling', 'topping', 'toping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'taped', 'aped', 'ape', 'ae', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'ape', 'ae', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampeded', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'ate', 'ae', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'ate', 'at', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'hae', 'ae', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'hae', 'ha', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'hat', 'at', 'a']
# ['heathenry', 'heathery', 'heather', 'heater', 'hater', 'hate', 'hat', 'ha', 'a']
# ['staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['staunches', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['stampings', 'stamping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['stampings', 'stamping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['stampings', 'stamping', 'tamping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickling', 'pickling', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickling', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['macerates', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['barytones', 'barytone', 'baryton', 'barton', 'baron', 'barn', 'ban', 'an', 'a']
# ['barytones', 'barytone', 'baryton', 'barton', 'baron', 'barn', 'bar', 'ar', 'a']
# ['barytones', 'barytone', 'baryton', 'baryon', 'baron', 'barn', 'ban', 'an', 'a']
# ['barytones', 'barytone', 'baryton', 'baryon', 'baron', 'barn', 'bar', 'ar', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rate', 'ate', 'ae', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rates', 'rats', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rater', 'rate', 'ate', 'ae', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'raters', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'ratter', 'rater', 'rate', 'ate', 'ae', 'a']
# ['prattlers', 'rattlers', 'ratters', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'ratters', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'rattlers', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'ae', 'a']
# ['prattlers', 'rattlers', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'rattlers', 'rattler', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['prattlers', 'prattler', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'ae', 'a']
# ['prattlers', 'prattler', 'rattler', 'ratter', 'rater', 'rate', 'ate', 'at', 'a']
# ['prattlers', 'prattler', 'rattler', 'ratter', 'rater', 'rate', 'rat', 'at', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'pare', 'are', 'ae', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'pare', 'are', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'pare', 'par', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'pare', 'par', 'pa', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'spar', 'par', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'spar', 'par', 'pa', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'spar', 'spa', 'pa', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'spare', 'spae', 'spa', 'pa', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'pare', 'are', 'ae', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'pare', 'are', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'pare', 'par', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'pare', 'par', 'pa', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'parr', 'arr', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'parr', 'par', 'ar', 'a']
# ['sparklers', 'sparkler', 'sparker', 'sparer', 'parer', 'parr', 'par', 'pa', 'a']
# ['scrappier', 'crappier', 'crapper', 'capper', 'caper', 'cape', 'ape', 'ae', 'a']
# ['scrappier', 'crappier', 'crapper', 'capper', 'caper', 'cape', 'cap', 'ca', 'a']
# ['scrappier', 'crappier', 'crapper', 'rapper', 'raper', 'rape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'crapper', 'capper', 'caper', 'cape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'crapper', 'capper', 'caper', 'cape', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'crapper', 'rapper', 'raper', 'rape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'scape', 'cape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'scape', 'cape', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'cape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'cape', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'rape', 'ape', 'ae', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'crape', 'crap', 'cap', 'ca', 'a']
# ['scrappier', 'scrapper', 'scraper', 'scrape', 'scrap', 'crap', 'cap', 'ca', 'a']
# ['stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'ae', 'a']
# ['stanchest', 'stanches', 'stances', 'stance', 'stane', 'sane', 'ane', 'an', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'later', 'late', 'ate', 'ae', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'later', 'late', 'ate', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'later', 'late', 'lat', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'later', 'late', 'lat', 'la', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'late', 'ate', 'ae', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'late', 'ate', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'late', 'lat', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'late', 'lat', 'la', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'pate', 'ate', 'ae', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'pate', 'ate', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'pate', 'pat', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'pate', 'pat', 'pa', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'plat', 'pat', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'plat', 'pat', 'pa', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'plat', 'lat', 'at', 'a']
# ['pilasters', 'pilaster', 'plaster', 'plater', 'plate', 'plat', 'lat', 'la', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'later', 'late', 'ate', 'ae', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'later', 'late', 'ate', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'later', 'late', 'lat', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'later', 'late', 'lat', 'la', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'late', 'ate', 'ae', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'late', 'ate', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'late', 'lat', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'late', 'lat', 'la', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'pate', 'ate', 'ae', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'pate', 'ate', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'pate', 'pat', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'pate', 'pat', 'pa', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'plat', 'pat', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'plat', 'pat', 'pa', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'plat', 'lat', 'at', 'a']
# ['pilasters', 'plasters', 'plaster', 'plater', 'plate', 'plat', 'lat', 'la', 'a']
# ['threaders', 'threader', 'treader', 'trader', 'trade', 'trad', 'rad', 'ad', 'a']
# ['threaders', 'threader', 'treader', 'trader', 'trade', 'trad', 'tad', 'ad', 'a']
# ['threaders', 'threader', 'treader', 'trader', 'trade', 'trad', 'tad', 'ta', 'a']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pin', 'in', 'i']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pin', 'pi', 'i']
# ['piercings', 'piercing', 'piecing', 'pieing', 'piing', 'ping', 'pig', 'pi', 'i']
# ['graftings', 'gratings', 'gratins', 'grains', 'rains', 'rain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'rains', 'rain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'rains', 'rain', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'rain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'rain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'rain', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'gain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'gain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'gain', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'gran', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grain', 'gran', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'gains', 'gain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'gains', 'gain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'gains', 'gain', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grans', 'gran', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'grains', 'grans', 'gran', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'rain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'rain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'rain', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'gain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'gain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'gain', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'gran', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'gratins', 'gratin', 'grain', 'gran', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'rain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'rain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'rain', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'gain', 'ain', 'ai', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'gain', 'ain', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'gain', 'gan', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'gran', 'ran', 'an', 'a']
# ['graftings', 'gratings', 'grating', 'gratin', 'grain', 'gran', 'gan', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'rain', 'ain', 'ai', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'rain', 'ain', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'rain', 'ran', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'gain', 'ain', 'ai', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'gain', 'ain', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'gain', 'gan', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'gran', 'ran', 'an', 'a']
# ['graftings', 'grafting', 'grating', 'gratin', 'grain', 'gran', 'gan', 'an', 'a']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['scrapping', 'crapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['springers', 'springer', 'springe', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splitting', 'slitting', 'sitting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splitting', 'spitting', 'sitting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'in', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'ting', 'tin', 'ti', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'in', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sin', 'si', 'i']
# ['splitting', 'spitting', 'spiting', 'siting', 'sting', 'sing', 'sig', 'si', 'i']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'pace', 'ace', 'ac', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'pace', 'ace', 'ae', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'aces', 'ace', 'ac', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'paces', 'aces', 'ace', 'ae', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'peace', 'pace', 'ace', 'ac', 'a']
# ['preachers', 'preaches', 'peaches', 'peaces', 'peace', 'pace', 'ace', 'ae', 'a']
# ['twaddling', 'waddling', 'wadding', 'adding', 'dding', 'ding', 'din', 'in', 'i']
# ['twaddling', 'waddling', 'wadding', 'adding', 'dding', 'ding', 'din', 'di', 'i']
# ['twaddling', 'waddling', 'wadding', 'adding', 'dding', 'ding', 'dig', 'di', 'i']
# ['twaddling', 'waddling', 'addling', 'adding', 'dding', 'ding', 'din', 'in', 'i']
# ['twaddling', 'waddling', 'addling', 'adding', 'dding', 'ding', 'din', 'di', 'i']
# ['twaddling', 'waddling', 'addling', 'adding', 'dding', 'ding', 'dig', 'di', 'i']
# ['prickings', 'pickings', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickings', 'pickings', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickings', 'pickings', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['prickings', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'in', 'i']
# ['prickings', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pin', 'pi', 'i']
# ['prickings', 'pricking', 'picking', 'piking', 'piing', 'ping', 'pig', 'pi', 'i']
# ['strippers', 'stripers', 'stripes', 'strips', 'trips', 'tips', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'stripes', 'strips', 'trips', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'stripes', 'strips', 'strip', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'stripes', 'stripe', 'tripe', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'stripes', 'stripe', 'strip', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'stripes', 'stipes', 'sties', 'ties', 'tie', 'ti', 'i']
# ['strippers', 'stripers', 'striper', 'stripe', 'tripe', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripers', 'striper', 'stripe', 'strip', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripper', 'striper', 'stripe', 'tripe', 'trip', 'tip', 'ti', 'i']
# ['strippers', 'stripper', 'striper', 'stripe', 'strip', 'trip', 'tip', 'ti', 'i']
# ['relievers', 'reliever', 'relieve', 'relive', 'reive', 'rive', 'riv', 'iv', 'i']
# ['relievers', 'relieves', 'relieve', 'relive', 'reive', 'rive', 'riv', 'iv', 'i']
# ['relievers', 'relieves', 'relives', 'relive', 'reive', 'rive', 'riv', 'iv', 'i']
# ['splitters', 'splitter', 'slitter', 'litter', 'liter', 'lite', 'lit', 'it', 'i']
# ['splitters', 'splitter', 'slitter', 'litter', 'liter', 'lite', 'lit', 'li', 'i']
# ['splitters', 'splitter', 'slitter', 'litter', 'liter', 'lite', 'lie', 'li', 'i']
# ['flashiest', 'flashest', 'flashes', 'lashes', 'lases', 'lass', 'ass', 'as', 'a']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringier', 'stingier', 'stinger', 'singer', 'singe', 'sine', 'sin', 'si', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringier', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'si', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'bis', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'bis', 'bi', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'bid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bids', 'bid', 'bi', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'ides', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'ides', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bide', 'bid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bides', 'bide', 'bid', 'bi', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'rids', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'rids', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'rids', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'ides', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'ides', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'rides', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bride', 'bide', 'bid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bride', 'bide', 'bid', 'bi', 'i']
# ['abridgers', 'abridges', 'bridges', 'brides', 'bride', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'rids', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'rids', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'rids', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'ides', 'ids', 'is', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'ides', 'ids', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'rides', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'ridges', 'ridge', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'bridge', 'bride', 'bide', 'bid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'bridge', 'bride', 'bide', 'bid', 'bi', 'i']
# ['abridgers', 'abridges', 'bridges', 'bridge', 'bride', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'bridges', 'bridge', 'ridge', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'abridge', 'bridge', 'bride', 'bide', 'bid', 'id', 'i']
# ['abridgers', 'abridges', 'abridge', 'bridge', 'bride', 'bide', 'bid', 'bi', 'i']
# ['abridgers', 'abridges', 'abridge', 'bridge', 'bride', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridges', 'abridge', 'bridge', 'ridge', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridger', 'abridge', 'bridge', 'bride', 'bide', 'bid', 'id', 'i']
# ['abridgers', 'abridger', 'abridge', 'bridge', 'bride', 'bide', 'bid', 'bi', 'i']
# ['abridgers', 'abridger', 'abridge', 'bridge', 'bride', 'ride', 'rid', 'id', 'i']
# ['abridgers', 'abridger', 'abridge', 'bridge', 'ridge', 'ride', 'rid', 'id', 'i']
# ['catchings', 'catching', 'caching', 'aching', 'ching', 'hing', 'hin', 'in', 'i']
# ['catchings', 'catching', 'caching', 'aching', 'ching', 'hing', 'hin', 'hi', 'i']
# ['catchings', 'catching', 'caching', 'aching', 'ching', 'chin', 'hin', 'in', 'i']
# ['catchings', 'catching', 'caching', 'aching', 'ching', 'chin', 'hin', 'hi', 'i']
# ['catchings', 'catching', 'caching', 'aching', 'ching', 'chin', 'chi', 'hi', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'tain', 'ain', 'ai', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'tain', 'ain', 'in', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'tain', 'tin', 'in', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'tain', 'tin', 'ti', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'akin', 'ain', 'ai', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'akin', 'ain', 'in', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'akin', 'kin', 'in', 'i']
# ['trackings', 'tracking', 'tacking', 'taking', 'takin', 'akin', 'kin', 'ki', 'i']
# ['drownings', 'drowning', 'downing', 'owning', 'owing', 'wing', 'win', 'in', 'i']
# ['laminates', 'laminate', 'laminae', 'lamina', 'lamia', 'lama', 'lam', 'am', 'a']
# ['laminates', 'laminate', 'laminae', 'lamina', 'lamia', 'lama', 'lam', 'la', 'a']
# ['breaching', 'beaching', 'baching', 'aching', 'ching', 'hing', 'hin', 'in', 'i']
# ['breaching', 'beaching', 'baching', 'aching', 'ching', 'hing', 'hin', 'hi', 'i']
# ['breaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'hin', 'in', 'i']
# ['breaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'hin', 'hi', 'i']
# ['breaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'chi', 'hi', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'satin', 'sain', 'ain', 'ai', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'satin', 'sain', 'ain', 'in', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'satin', 'sain', 'sin', 'in', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'satin', 'sain', 'sin', 'si', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'sting', 'ting', 'tin', 'in', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'sting', 'ting', 'tin', 'ti', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'sting', 'sing', 'sin', 'in', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'sting', 'sing', 'sin', 'si', 'i']
# ['sweatings', 'sweating', 'seating', 'sating', 'sting', 'sing', 'sig', 'si', 'i']
# ['sparkling', 'sparling', 'sparing', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['sparkling', 'sparking', 'sparing', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['ministers', 'minsters', 'minters', 'inters', 'inter', 'intr', 'int', 'it', 'i']
# ['ministers', 'minsters', 'minters', 'inters', 'inter', 'intr', 'int', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'inter', 'intr', 'int', 'it', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'inter', 'intr', 'int', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'mines', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'mines', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minters', 'miners', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minsters', 'minster', 'minter', 'inter', 'intr', 'int', 'it', 'i']
# ['ministers', 'minsters', 'minster', 'minter', 'inter', 'intr', 'int', 'in', 'i']
# ['ministers', 'minsters', 'minster', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minsters', 'minster', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'inter', 'intr', 'int', 'it', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'inter', 'intr', 'int', 'in', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'miner', 'mine', 'min', 'in', 'i']
# ['ministers', 'minister', 'minster', 'minter', 'miner', 'mine', 'min', 'mi', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'si', 'i']
# ['starlings', 'starling', 'staring', 'string', 'sting', 'sing', 'sig', 'si', 'i']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'colons', 'coons', 'coos', 'cos', 'os']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'colons', 'coons', 'cons', 'cos', 'os']
# ['colonizers', 'colonizes', 'colonies', 'colones', 'clones', 'cones', 'cons', 'cos', 'os']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'tain', 'ain', 'ai', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'tain', 'ain', 'in', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'tain', 'tin', 'in', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'tain', 'tin', 'ti', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'akin', 'ain', 'ai', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'akin', 'ain', 'in', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'akin', 'kin', 'in', 'i']
# ['stalkings', 'stalking', 'talking', 'taking', 'takin', 'akin', 'kin', 'ki', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'tain', 'ain', 'ai', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'tain', 'ain', 'in', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'tain', 'tin', 'in', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'tain', 'tin', 'ti', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'akin', 'ain', 'ai', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'akin', 'ain', 'in', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'akin', 'kin', 'in', 'i']
# ['stalkings', 'stalking', 'staking', 'taking', 'takin', 'akin', 'kin', 'ki', 'i']
# ['brassiest', 'brassies', 'brasses', 'basses', 'bases', 'bass', 'ass', 'as', 'a']
# ['refractory', 'refractor', 'refactor', 'reactor', 'rector', 'recto', 'rect', 'rec', 're']
# ['refractors', 'refactors', 'reactors', 'rectors', 'rectos', 'recto', 'rect', 'rec', 're']
# ['refractors', 'refactors', 'reactors', 'rectors', 'rector', 'recto', 'rect', 'rec', 're']
# ['refractors', 'refactors', 'reactors', 'reactor', 'rector', 'recto', 'rect', 'rec', 're']
# ['refractors', 'refactors', 'refactor', 'reactor', 'rector', 'recto', 'rect', 'rec', 're']
# ['refractors', 'refractor', 'refactor', 'reactor', 'rector', 'recto', 'rect', 'rec', 're']
# ['islanders', 'slanders', 'sanders', 'sander', 'saner', 'sane', 'ane', 'ae', 'a']
# ['islanders', 'slanders', 'sanders', 'sander', 'saner', 'sane', 'ane', 'an', 'a']
# ['islanders', 'slanders', 'slander', 'sander', 'saner', 'sane', 'ane', 'ae', 'a']
# ['islanders', 'slanders', 'slander', 'sander', 'saner', 'sane', 'ane', 'an', 'a']
# ['islanders', 'islander', 'slander', 'sander', 'saner', 'sane', 'ane', 'ae', 'a']
# ['islanders', 'islander', 'slander', 'sander', 'saner', 'sane', 'ane', 'an', 'a']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strapping', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['strapping', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trappings', 'trapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trappings', 'trapping', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trappings', 'tappings', 'tapping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['bleaching', 'beaching', 'baching', 'aching', 'ching', 'hing', 'hin', 'in', 'i']
# ['bleaching', 'beaching', 'baching', 'aching', 'ching', 'hing', 'hin', 'hi', 'i']
# ['bleaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'hin', 'in', 'i']
# ['bleaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'hin', 'hi', 'i']
# ['bleaching', 'beaching', 'baching', 'aching', 'ching', 'chin', 'chi', 'hi', 'i']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'as', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'la', 'a']
# ['cleansers', 'cleanses', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clans', 'cans', 'ans', 'as', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'ca', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'clan', 'can', 'an', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'clean', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'lean', 'lea', 'ea', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'la', 'a']
# ['cleansers', 'cleanser', 'cleanse', 'cleans', 'leans', 'leas', 'lea', 'ea', 'a']
# ['shinglier', 'shingler', 'shingle', 'single', 'singe', 'sing', 'sin', 'in', 'i']
# ['shinglier', 'shingler', 'shingle', 'single', 'singe', 'sing', 'sin', 'si', 'i']
# ['shinglier', 'shingler', 'shingle', 'single', 'singe', 'sing', 'sig', 'si', 'i']
# ['shinglier', 'shingler', 'shingle', 'single', 'singe', 'sine', 'sin', 'in', 'i']
# ['shinglier', 'shingler', 'shingle', 'single', 'singe', 'sine', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sis', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sis', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'ins', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'ins', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sins', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sing', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sings', 'sing', 'sig', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sis', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sis', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'ins', 'is', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'ins', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sins', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'sines', 'sine', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singes', 'singe', 'sine', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'singers', 'singer', 'singe', 'sine', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stingers', 'stinger', 'singer', 'singe', 'sine', 'sin', 'si', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'in', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sin', 'si', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sing', 'sig', 'si', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'in', 'i']
# ['stringers', 'stringer', 'stinger', 'singer', 'singe', 'sine', 'sin', 'si', 'i']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rates', 'rate', 'ate', 'ae', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rates', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rates', 'rate', 'rat', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rates', 'rats', 'rat', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rater', 'rate', 'ate', 'ae', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raters', 'rater', 'rate', 'rat', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raster', 'rater', 'rate', 'ate', 'ae', 'a']
# ['roadsters', 'roasters', 'rasters', 'raster', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roasters', 'rasters', 'raster', 'rater', 'rate', 'rat', 'at', 'a']
# ['roadsters', 'roasters', 'roaster', 'raster', 'rater', 'rate', 'ate', 'ae', 'a']
# ['roadsters', 'roasters', 'roaster', 'raster', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roasters', 'roaster', 'raster', 'rater', 'rate', 'rat', 'at', 'a']
# ['roadsters', 'roadster', 'roaster', 'raster', 'rater', 'rate', 'ate', 'ae', 'a']
# ['roadsters', 'roadster', 'roaster', 'raster', 'rater', 'rate', 'ate', 'at', 'a']
# ['roadsters', 'roadster', 'roaster', 'raster', 'rater', 'rate', 'rat', 'at', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'cat', 'ca', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'cat', 'at', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'can', 'ca', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'can', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'ant', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cant', 'ant', 'at', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cats', 'cat', 'ca', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cats', 'cat', 'at', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cans', 'can', 'ca', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cans', 'can', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cans', 'ans', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'cans', 'ans', 'as', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'ants', 'ant', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'ants', 'ant', 'at', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'ants', 'ans', 'an', 'a']
# ['acanthous', 'acanthus', 'canthus', 'cantus', 'cants', 'ants', 'ans', 'as', 'a']
# ['stoppings', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'in', 'i']
# ['stoppings', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['stoppings', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['stoppings', 'toppings', 'topping', 'toping', 'oping', 'ping', 'pin', 'in', 'i']
# ['stoppings', 'toppings', 'topping', 'toping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['stoppings', 'toppings', 'topping', 'toping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['switchers', 'switches', 'witches', 'withes', 'withe', 'wite', 'wit', 'it', 'i']
# ['switchers', 'switches', 'witches', 'withes', 'withe', 'with', 'wit', 'it', 'i']
# ['startling', 'starting', 'stating', 'sating', 'satin', 'sain', 'ain', 'ai', 'i']
# ['startling', 'starting', 'stating', 'sating', 'satin', 'sain', 'ain', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'satin', 'sain', 'sin', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'satin', 'sain', 'sin', 'si', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'sing', 'sin', 'in', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'sing', 'sin', 'si', 'i']
# ['startling', 'starting', 'stating', 'sating', 'sting', 'sing', 'sig', 'si', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'sing', 'sin', 'si', 'i']
# ['startling', 'starting', 'staring', 'string', 'sting', 'sing', 'sig', 'si', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'in', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'ting', 'tin', 'ti', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'in', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'sing', 'sin', 'si', 'i']
# ['startling', 'starling', 'staring', 'string', 'sting', 'sing', 'sig', 'si', 'i']
# ['stropping', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'in', 'i']
# ['stropping', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pin', 'pi', 'i']
# ['stropping', 'stopping', 'topping', 'toping', 'oping', 'ping', 'pig', 'pi', 'i']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'aped', 'ape', 'ae', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'ape', 'ae', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'taped', 'tape', 'tap', 'ta', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'am', 'a']
# ['stampedes', 'stampede', 'stamped', 'tamped', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sis', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'sits', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'site', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'sites', 'site', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sis', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'sits', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pis', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'pits', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spits', 'spit', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pis', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spies', 'pies', 'pie', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'pit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'spit', 'pit', 'pi', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'site', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'spites', 'spite', 'site', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'sis', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'sis', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'its', 'is', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'its', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'sit', 'it', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'sits', 'sit', 'si', 'i']
# ['spritzers', 'spritzes', 'sprites', 'sprits', 'spits', 'pits', 'pis', 'is', 'i']
# ...
# ['bleachers', 'bleaches', 'leaches', 'laches', 'laces', 'lace', 'lac', 'la', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'laces', 'aces', 'ace', 'ac', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'laces', 'aces', 'ace', 'ae', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'aches', 'aces', 'ace', 'ac', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'aches', 'aces', 'ace', 'ae', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'aches', 'ache', 'ace', 'ac', 'a']
# ['bleachers', 'bleaches', 'leaches', 'laches', 'aches', 'ache', 'ace', 'ae', 'a']
# ['bleachers', 'bleaches', 'beaches', 'baches', 'aches', 'aces', 'ace', 'ac', 'a']
# ['bleachers', 'bleaches', 'beaches', 'baches', 'aches', 'aces', 'ace', 'ae', 'a']
# ['bleachers', 'bleaches', 'beaches', 'baches', 'aches', 'ache', 'ace', 'ac', 'a']
# ['bleachers', 'bleaches', 'beaches', 'baches', 'aches', 'ache', 'ace', 'ae', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['macerated', 'macerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['threadier', 'threader', 'treader', 'trader', 'trade', 'trad', 'rad', 'ad', 'a']
# ['threadier', 'threader', 'treader', 'trader', 'trade', 'trad', 'tad', 'ad', 'a']
# ['threadier', 'threader', 'treader', 'trader', 'trade', 'trad', 'tad', 'ta', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['acerbated', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['acerbates', 'acerbate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pin', 'in', 'i']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pin', 'pi', 'i']
# ['paintings', 'painting', 'paining', 'pining', 'piing', 'ping', 'pig', 'pi', 'i']
# ['strappers', 'trappers', 'tappers', 'tapers', 'tapes', 'apes', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'tappers', 'tapers', 'tapes', 'tape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'tappers', 'tapers', 'tapes', 'tape', 'tap', 'ta', 'a']
# ['strappers', 'trappers', 'tappers', 'tapers', 'tapes', 'taps', 'tap', 'ta', 'a']
# ['strappers', 'trappers', 'tappers', 'tapers', 'taper', 'tape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'tappers', 'tapers', 'taper', 'tape', 'tap', 'ta', 'a']
# ['strappers', 'trappers', 'tappers', 'tapper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'tappers', 'tapper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['strappers', 'trappers', 'rappers', 'rapers', 'rapes', 'apes', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'rappers', 'rapers', 'rapes', 'rape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'rappers', 'rapers', 'raper', 'rape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'rappers', 'rapper', 'raper', 'rape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'trapper', 'tapper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['strappers', 'trappers', 'trapper', 'tapper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['strappers', 'trappers', 'trapper', 'rapper', 'raper', 'rape', 'ape', 'ae', 'a']
# ['strappers', 'strapper', 'trapper', 'tapper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['strappers', 'strapper', 'trapper', 'tapper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['strappers', 'strapper', 'trapper', 'rapper', 'raper', 'rape', 'ape', 'ae', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'elate', 'late', 'ate', 'ae', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'elate', 'late', 'ate', 'at', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'elate', 'late', 'lat', 'at', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'elate', 'late', 'lat', 'la', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'lated', 'late', 'ate', 'ae', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'lated', 'late', 'ate', 'at', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'lated', 'late', 'lat', 'at', 'a']
# ['refloated', 'reflated', 'related', 'elated', 'lated', 'late', 'lat', 'la', 'a']
# ['refloated', 'reflated', 'related', 'relate', 'elate', 'late', 'ate', 'ae', 'a']
# ['refloated', 'reflated', 'related', 'relate', 'elate', 'late', 'ate', 'at', 'a']
# ['refloated', 'reflated', 'related', 'relate', 'elate', 'late', 'lat', 'at', 'a']
# ['refloated', 'reflated', 'related', 'relate', 'elate', 'late', 'lat', 'la', 'a']
# ['refloated', 'reflated', 'reflate', 'relate', 'elate', 'late', 'ate', 'ae', 'a']
# ['refloated', 'reflated', 'reflate', 'relate', 'elate', 'late', 'ate', 'at', 'a']
# ['refloated', 'reflated', 'reflate', 'relate', 'elate', 'late', 'lat', 'at', 'a']
# ['refloated', 'reflated', 'reflate', 'relate', 'elate', 'late', 'lat', 'la', 'a']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'in', 'i']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['wrappings', 'wrapping', 'rapping', 'raping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['splatters', 'splatter', 'platter', 'plater', 'later', 'late', 'ate', 'ae', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'late', 'ate', 'ae', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'late', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'late', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'pate', 'ate', 'ae', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'pate', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'pate', 'pat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'pate', 'pat', 'pa', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'plat', 'pat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'plat', 'pat', 'pa', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'plat', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'plater', 'plate', 'plat', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'ate', 'ae', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'ate', 'ae', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'ate', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'lat', 'at', 'a']
# ['splatters', 'splatter', 'platter', 'latter', 'latte', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'later', 'late', 'ate', 'ae', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'late', 'ate', 'ae', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'pate', 'ate', 'ae', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'pate', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'pate', 'pat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'pate', 'pat', 'pa', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'plat', 'pat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'plat', 'pat', 'pa', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'plat', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'plater', 'plate', 'plat', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'ate', 'ae', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'later', 'late', 'lat', 'la', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'ate', 'ae', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'ate', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'lat', 'at', 'a']
# ['splatters', 'platters', 'platter', 'latter', 'latte', 'late', 'lat', 'la', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lace', 'ace', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lace', 'ace', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lace', 'lac', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lace', 'lac', 'la', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lane', 'ane', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'launce', 'lance', 'lane', 'ane', 'an', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lace', 'ace', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lace', 'ace', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lace', 'lac', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lace', 'lac', 'la', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lane', 'ane', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lance', 'lane', 'ane', 'an', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'lace', 'ace', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'lace', 'ace', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'lace', 'lac', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'lace', 'lac', 'la', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'aces', 'ace', 'ac', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'laces', 'aces', 'ace', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lanes', 'lane', 'ane', 'ae', 'a']
# ['launchers', 'launches', 'launces', 'lances', 'lanes', 'lane', 'ane', 'an', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'apes', 'ape', 'ae', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'tape', 'ape', 'ae', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'tapes', 'taps', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'taper', 'tape', 'ape', 'ae', 'a']
# ['tramplers', 'trampers', 'tampers', 'tapers', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tams', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tams', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tames', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tampers', 'tamers', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampers', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'taper', 'tape', 'ape', 'ae', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'taper', 'tape', 'tap', 'ta', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'am', 'a']
# ['tramplers', 'trampler', 'tramper', 'tamper', 'tamer', 'tame', 'tam', 'ta', 'a']
# ['laminated', 'laminate', 'laminae', 'lamina', 'lamia', 'lama', 'lam', 'am', 'a']
# ['laminated', 'laminate', 'laminae', 'lamina', 'lamia', 'lama', 'lam', 'la', 'a']
# ['streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'am', 'a']
# ['streambed', 'streamed', 'steamed', 'teamed', 'tamed', 'tame', 'tam', 'ta', 'a']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'in', 'i']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pin', 'pi', 'i']
# ['trampling', 'tramping', 'tamping', 'taping', 'aping', 'ping', 'pig', 'pi', 'i']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'sate', 'ate', 'ae', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'sate', 'ate', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'sate', 'sat', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'tat', 'at', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'tat', 'ta', 'a']
# ['restarted', 'restated', 'restate', 'estate', 'state', 'stat', 'sat', 'at', 'a']
# ['springier', 'springer', 'springe', 'spring', 'sprig', 'prig', 'pig', 'pi', 'i']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['lacerated', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'ae', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'ate', 'at', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'ca', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'cate', 'cat', 'at', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'ae', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'ate', 'at', 'a']
# ['lacerates', 'lacerate', 'acerate', 'cerate', 'crate', 'rate', 'rat', 'at', 'a']
